# %%
import pandas as pd
import os

# %%
directory = './intent/'
dataframes = []

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)

combined_df.head()
# Out:
#          Date                              From  \
# 0  2000-12-04          ["'dan.hyvl@enron.com'"]
# 1  2000-12-08     ["'james.steffes@enron.com'"]
# 2  2000-11-27       ["'susan.scott@enron.com'"]
# 3  2000-09-20  ["'shirley.crenshaw@enron.com'"]
# 4  2001-10-23        ["'d..steffes@enron.com'"]
#
#                                                   To  \
# 0                           ["'mcesario@ormet.com'"]
# 1                       ["'kevin.presto@enron.com'"]
# 2                        ["'mary.miller@enron.com'"]
# 3  ["'zimin.lu@enron.com'", " 'vasant.shanbhogue@...
# 4                         ["'jean.ryall@enron.com'"]
#
#                                              Subject  \
# 0                          Re: Transaction Agreement
# 1                                 RTO Status 12.8.00
# 2                                           Cal. GIR
# 3  Re: Informal Interview with the Enron Research...
# 4                                                RE:
#
#                                                 Body      Time  \
# 0  exhibit c and exhibit d mike cesario mcesarioo...  06:14:00
# 1  kevin attached is the east power rto status ma...  09:36:00
# 2  for your information the outcome was great for...  01:29:00
# 3  fyi i have arranged the following interview sc...  08:47:00
# 4  thanks if you need any additional support pls ...  08:41:42
#
#                                      Intent and Data Unnamed: 7
# 0                                                 No        NaN
# 1                                                 No        NaN
# 2                                                 No        NaN
# 3  Yes\n[\n    {\n        "sender": "shirley.cren...        NaN
# 4                                                 No        NaN

# %%
combined_df.shape
# Out:
# (12500, 8)

# %%
combined_df['Unnamed: 7'].isna().sum()
# Out:
# 12499

# %%
combined_df['Unnamed: 7']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 12495    NaN
# 12496    NaN
# 12497    NaN
# 12498    NaN
# 12499    NaN
# Name: Unnamed: 7, Length: 12500, dtype: object

# %%
combined_df = combined_df.drop('Unnamed: 7', axis='columns')
combined_df = combined_df.drop_duplicates()

# %%
combined_df
# Out:
#              Date                              From  \
# 0      2000-12-04          ["'dan.hyvl@enron.com'"]
# 1      2000-12-08     ["'james.steffes@enron.com'"]
# 2      2000-11-27       ["'susan.scott@enron.com'"]
# 3      2000-09-20  ["'shirley.crenshaw@enron.com'"]
# 4      2001-10-23        ["'d..steffes@enron.com'"]
# ...           ...                               ...
# 12494  2000-12-13    ["'robin.rodrigue@enron.com'"]
# 12495  2000-10-25    ["'hunter.shively@enron.com'"]
# 12497  2001-06-27      ["'outlook.team@enron.com'"]
# 12498  2000-10-13   ["'gareth.bahlmann@enron.com'"]
# 12499  2000-11-17        ["'slava.brin@chase.com'"]
#
#                                                       To  \
# 0                               ["'mcesario@ormet.com'"]
# 1                           ["'kevin.presto@enron.com'"]
# 2                            ["'mary.miller@enron.com'"]
# 3      ["'zimin.lu@enron.com'", " 'vasant.shanbhogue@...
# 4                             ["'jean.ryall@enron.com'"]
# ...                                                  ...
# 12494                     ["'gabriel.monroy@enron.com'"]
# 12495                      ["'john.lavorato@enron.com'"]
# 12497                                                NaN
# 12498  ["'kay.mann@enron.com'", " 'travis.mccullough@...
# 12499  ["'sbhargava@baincap.com'", " 'jwoolbert@bainc...
#
#                                                  Subject  \
# 0                              Re: Transaction Agreement
# 1                                     RTO Status 12.8.00
# 2                                               Cal. GIR
# 3      Re: Informal Interview with the Enron Research...
# 4                                                    RE:
# ...                                                  ...
# 12494                                   Re: I'm Safe Now
# 12495                                               PIRA
# 12497                             Martha/Donna Dashboard
# 12498                            Term sheets for Manlove
# 12499                          Conference Call on Monday
#
#                                                     Body      Time  \
# 0      exhibit c and exhibit d mike cesario mcesarioo...  06:14:00
# 1      kevin attached is the east power rto status ma...  09:36:00
# 2      for your information the outcome was great for...  01:29:00
# 3      fyi i have arranged the following interview sc...  08:47:00
# 4      thanks if you need any additional support pls ...  08:41:42
# ...                                                  ...       ...
# 12494  im low on clean clothesi need to think if i ha...  10:10:00
# 12495  forwarded by hunter s shivelyhouect on one zer...  07:16:00
# 12497  calendar entry appointment description marthad...  16:02:00
# 12498  attached are the draft termsheets substantiall...  06:53:00
# 12499  please note the conference call information fo...  06:36:00
#
#                                          Intent and Data
# 0                                                     No
# 1                                                     No
# 2                                                     No
# 3      Yes\n[\n    {\n        "sender": "shirley.cren...
# 4                                                     No
# ...                                                  ...
# 12494  Yes\n[\n'sender': 'robin.rodrigue@enron.com',\...
# 12495  Yes\n[\n    {\n        'sender': 'hunter.shive...
# 12497                                                 No
# 12498                                                 No
# 12499  Yes\n[\n    {\n        "sender": "slava.brin@c...
#
# [11767 rows x 7 columns]
